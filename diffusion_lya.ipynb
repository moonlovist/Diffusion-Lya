# %%
import os
import glob
import numpy as np
from astropy.io import fits
from astropy.table import Table
import matplotlib.pyplot as plt

# %%
f=fits.open('/global/cfs/cdirs/desi/users/tingtan/CSST_forecast/DLA_forecast/mock_set1/csst_qso_097_z3.36_low.fits')

# %%
f[1].data,f[2].data
# Out:
# (array([2000.    , 2001.0002, 2002.001 , ..., 7993.6475, 7997.6455,
#         8001.6455], dtype=float32),
#  array([2.4221126e-18, 2.0751257e-18, 0.0000000e+00, ..., 5.9215275e-18,
#         5.8297142e-18, 6.6920907e-19], dtype=float32))

# %%
plt.plot(f[1].data,f[2].data)

# %%
plt.plot(f[1].data,f[2].data)
plt.ylim(0,0.5e-17)
# Out:
# (0.0, 5e-18)

# %%
plt.plot(f[1].data,f[2].data)
plt.ylim(0,1.5)
# Out:
# (0.0, 1.5)
